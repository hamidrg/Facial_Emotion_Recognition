# %%
import tensorflow as tf
from tensorflow import keras
import os
from PIL import Image
import numpy as np

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("kmirfan/micro-expressions")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/kmirfan/micro-expressions?dataset_version_number=2...
# 100%|██████████| 36.3M/36.3M [00:02<00:00, 14.1MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/kmirfan/micro-expressions/versions/2

# %%
from keras.utils import to_categorical

# Define the paths to the dataset directories
train_dir = path + '/Micro_Expressions/train'
test_dir = path + '/Micro_Expressions/test'

# Define the image size and number of classes
img_size = (48, 48)
num_classes = 7


# Create a mapping from class names to numerical labels
class_names = ['anger', 'disgust', 'fear', 'happiness', 'neutral', 'sadness', 'surprise']
class_to_label = {class_name: i for i, class_name in enumerate(class_names)}
print(class_to_label)

# Function to load images and labels from a directory
def load_images_and_labels(directory, img_size, num_classes):
    images = []
    labels = []

    for class_name in os.listdir(directory):
        class_dir = os.path.join(directory, class_name)
        if not os.path.isdir(class_dir):
            continue

        # Get the numerical label for the current class
        label = class_to_label.get(class_name)
        if label is None:
            print(f"Skipping unknown class: {class_name}")
            continue

        print(f"Loading images from class: {class_name} (Label: {label})")

        for image_file in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image_file)
            try:
                # Load image in grayscale mode
                image = Image.open(image_path).convert('RGB')  # 'RGB' mode for grayscale
                image = image.resize(img_size)
                image = np.array(image) / 255.0  # Normalize pixel values to [0, 1]
                images.append(image)
                labels.append(label)
            except Exception as e:
                print(f"Error loading image {image_path}: {e}")

    images = np.array(images)
    labels = np.array(labels)

    # Convert labels to categorical format
    labels = to_categorical(labels, num_classes=num_classes)
    labels = labels.reshape((-1, num_classes))

    return images, labels

# Load all data from train and test directories
train_images, train_labels = load_images_and_labels(train_dir, img_size, num_classes)
test_images, test_labels = load_images_and_labels(test_dir, img_size, num_classes)

# Combine all data into a single dataset
all_images = np.concatenate((train_images, test_images), axis=0)
all_labels = np.concatenate((train_labels, test_labels), axis=0)

# Shuffle the combined dataset
indices = np.arange(all_images.shape[0])
np.random.shuffle(indices)

all_images = all_images[indices]
all_labels = all_labels[indices]

# Split the shuffled dataset into train, test, and val sets
train_size = int(0.9 * all_images.shape[0])  # 90% for training

train_images = all_images[:train_size]
train_labels = all_labels[:train_size]

test_images = all_images[train_size:]
test_labels = all_labels[train_size:]

# Print the shapes of the loaded data
print(f"Train images shape: {train_images.shape}")
print(f"Train labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Test labels shape: {test_labels.shape}")
# Out:
# {'anger': 0, 'disgust': 1, 'fear': 2, 'happiness': 3, 'neutral': 4, 'sadness': 5, 'surprise': 6}
# Loading images from class: sadness (Label: 5)
# Loading images from class: neutral (Label: 4)
# Loading images from class: happiness (Label: 3)
# Loading images from class: disgust (Label: 1)
# Loading images from class: anger (Label: 0)
# Loading images from class: fear (Label: 2)
# Loading images from class: surprise (Label: 6)
# Loading images from class: sadness (Label: 5)
# Loading images from class: neutral (Label: 4)
# Loading images from class: happiness (Label: 3)
# Loading images from class: disgust (Label: 1)
# Loading images from class: anger (Label: 0)
# Loading images from class: fear (Label: 2)
# Loading images from class: surprise (Label: 6)
# Train images shape: (8514, 48, 48, 3)
# Train labels shape: (8514, 7)
# Test images shape: (946, 48, 48, 3)
# Test labels shape: (946, 7)

# %%
import matplotlib.pyplot as plt

print(train_labels[5367])
plt.imshow(train_images[5367])
plt.show()
# Out:
# [0. 0. 0. 1. 0. 0. 0.]

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D
from keras.optimizers import Adam
from keras.layers import MaxPooling2D
from keras.regularizers import l2

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,3), kernel_regularizer=l2(0.001)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2(0.001)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2(0.001)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', kernel_regularizer=l2(0.001)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(1024, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)                    │ (None, 46, 46, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 44, 44, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 20, 20, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 10, 10, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1024)                │       2,098,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 7)                   │           7,175 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,346,183 (8.95 MB)
#  Trainable params: 2,346,183 (8.95 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import EarlyStopping

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
early_stop = EarlyStopping(monitor='val-accuracy', mode='max', patience=5, restore_best_weights=True)

hist = model.fit(train_images, train_labels, batch_size=32, epochs=50, shuffle=True, validation_data=(test_images, test_labels), callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.2492 - loss: 3.2644 - val_accuracy: 0.2595 - val_loss: 2.7729 - learning_rate: 1.0000e-04
# Epoch 2/50
#  11/237 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.2671 - loss: 2.7442
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val-accuracy` which is not available. Available metrics are: accuracy,loss,val_accuracy,val_loss
#   current = self.get_monitor_value(logs)
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.3236 - loss: 2.5828 - val_accuracy: 0.4746 - val_loss: 2.1453 - learning_rate: 1.0000e-04
# Epoch 3/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.4706 - loss: 2.1143 - val_accuracy: 0.5322 - val_loss: 1.9275 - learning_rate: 1.0000e-04
# Epoch 4/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5177 - loss: 1.9095 - val_accuracy: 0.5640 - val_loss: 1.7822 - learning_rate: 1.0000e-04
# Epoch 5/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5484 - loss: 1.7771 - val_accuracy: 0.5962 - val_loss: 1.6531 - learning_rate: 1.0000e-04
# Epoch 6/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5707 - loss: 1.6717 - val_accuracy: 0.6131 - val_loss: 1.5750 - learning_rate: 1.0000e-04
# Epoch 7/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.6072 - loss: 1.5564 - val_accuracy: 0.6422 - val_loss: 1.4852 - learning_rate: 1.0000e-04
# Epoch 8/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6270 - loss: 1.4912 - val_accuracy: 0.6459 - val_loss: 1.4255 - learning_rate: 1.0000e-04
# Epoch 9/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6396 - loss: 1.4330 - val_accuracy: 0.6644 - val_loss: 1.3725 - learning_rate: 1.0000e-04
# Epoch 10/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6622 - loss: 1.3577 - val_accuracy: 0.6607 - val_loss: 1.3506 - learning_rate: 1.0000e-04
# Epoch 11/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6756 - loss: 1.3133 - val_accuracy: 0.6845 - val_loss: 1.2924 - learning_rate: 1.0000e-04
# Epoch 12/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6871 - loss: 1.2612 - val_accuracy: 0.6961 - val_loss: 1.2612 - learning_rate: 1.0000e-04
# Epoch 13/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7124 - loss: 1.1791 - val_accuracy: 0.6871 - val_loss: 1.2395 - learning_rate: 1.0000e-04
# Epoch 14/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7028 - loss: 1.1820 - val_accuracy: 0.6987 - val_loss: 1.2131 - learning_rate: 1.0000e-04
# Epoch 15/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7267 - loss: 1.1240 - val_accuracy: 0.7019 - val_loss: 1.2071 - learning_rate: 1.0000e-04
# Epoch 16/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7418 - loss: 1.0735 - val_accuracy: 0.7056 - val_loss: 1.1879 - learning_rate: 1.0000e-04
# Epoch 17/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7540 - loss: 1.0694 - val_accuracy: 0.7225 - val_loss: 1.1491 - learning_rate: 1.0000e-04
# Epoch 18/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7652 - loss: 1.0323 - val_accuracy: 0.7236 - val_loss: 1.1371 - learning_rate: 1.0000e-04
# Epoch 19/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7676 - loss: 1.0034 - val_accuracy: 0.7294 - val_loss: 1.1278 - learning_rate: 1.0000e-04
# Epoch 20/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7832 - loss: 0.9775 - val_accuracy: 0.7336 - val_loss: 1.1102 - learning_rate: 1.0000e-04
# Epoch 21/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7873 - loss: 0.9492 - val_accuracy: 0.7357 - val_loss: 1.0989 - learning_rate: 1.0000e-04
# Epoch 22/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7966 - loss: 0.9172 - val_accuracy: 0.7400 - val_loss: 1.0951 - learning_rate: 1.0000e-04
# Epoch 23/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8103 - loss: 0.8918 - val_accuracy: 0.7431 - val_loss: 1.0953 - learning_rate: 1.0000e-04
# Epoch 24/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8139 - loss: 0.8654 - val_accuracy: 0.7421 - val_loss: 1.0901 - learning_rate: 1.0000e-04
# Epoch 25/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8149 - loss: 0.8655 - val_accuracy: 0.7537 - val_loss: 1.0631 - learning_rate: 1.0000e-04
# Epoch 26/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8261 - loss: 0.8255 - val_accuracy: 0.7579 - val_loss: 1.0617 - learning_rate: 1.0000e-04
# Epoch 27/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8348 - loss: 0.8090 - val_accuracy: 0.7627 - val_loss: 1.0671 - learning_rate: 1.0000e-04
# Epoch 28/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8439 - loss: 0.7886 - val_accuracy: 0.7637 - val_loss: 1.0484 - learning_rate: 1.0000e-04
# Epoch 29/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8465 - loss: 0.7766 - val_accuracy: 0.7595 - val_loss: 1.0582 - learning_rate: 1.0000e-04
# Epoch 30/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8594 - loss: 0.7532 - val_accuracy: 0.7643 - val_loss: 1.0452 - learning_rate: 1.0000e-04
# Epoch 31/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8666 - loss: 0.7282 - val_accuracy: 0.7622 - val_loss: 1.0505 - learning_rate: 1.0000e-04
# Epoch 32/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8666 - loss: 0.7375 - val_accuracy: 0.7685 - val_loss: 1.0486 - learning_rate: 1.0000e-04
# Epoch 33/50
# 235/237 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8786 - loss: 0.6927
# Epoch 33: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8785 - loss: 0.6930 - val_accuracy: 0.7637 - val_loss: 1.0544 - learning_rate: 1.0000e-04
# Epoch 34/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8865 - loss: 0.6763 - val_accuracy: 0.7727 - val_loss: 1.0579 - learning_rate: 5.0000e-05
# Epoch 35/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8964 - loss: 0.6438 - val_accuracy: 0.7632 - val_loss: 1.0732 - learning_rate: 5.0000e-05
# Epoch 36/50
# 233/237 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8898 - loss: 0.6454
# Epoch 36: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8899 - loss: 0.6453 - val_accuracy: 0.7706 - val_loss: 1.0563 - learning_rate: 5.0000e-05
# Epoch 37/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9093 - loss: 0.6007 - val_accuracy: 0.7701 - val_loss: 1.0539 - learning_rate: 2.5000e-05
# Epoch 38/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9179 - loss: 0.5820 - val_accuracy: 0.7743 - val_loss: 1.0518 - learning_rate: 2.5000e-05
# Epoch 39/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9153 - loss: 0.5710
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9153 - loss: 0.5710 - val_accuracy: 0.7785 - val_loss: 1.0572 - learning_rate: 2.5000e-05
# Epoch 40/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9053 - loss: 0.5978 - val_accuracy: 0.7754 - val_loss: 1.0485 - learning_rate: 1.2500e-05
# Epoch 41/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9169 - loss: 0.5774 - val_accuracy: 0.7775 - val_loss: 1.0552 - learning_rate: 1.2500e-05
# Epoch 42/50
# 233/237 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9176 - loss: 0.5718
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9176 - loss: 0.5718 - val_accuracy: 0.7754 - val_loss: 1.0600 - learning_rate: 1.2500e-05
# Epoch 43/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9210 - loss: 0.5621 - val_accuracy: 0.7759 - val_loss: 1.0531 - learning_rate: 6.2500e-06
# Epoch 44/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9228 - loss: 0.5656 - val_accuracy: 0.7775 - val_loss: 1.0532 - learning_rate: 6.2500e-06
# Epoch 45/50
# 232/237 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9263 - loss: 0.5541
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9262 - loss: 0.5542 - val_accuracy: 0.7748 - val_loss: 1.0568 - learning_rate: 6.2500e-06
# Epoch 46/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9144 - loss: 0.5616 - val_accuracy: 0.7733 - val_loss: 1.0593 - learning_rate: 3.1250e-06
# Epoch 47/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9174 - loss: 0.5626 - val_accuracy: 0.7764 - val_loss: 1.0554 - learning_rate: 3.1250e-06
# Epoch 48/50
# 234/237 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9169 - loss: 0.5699
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9169 - loss: 0.5699 - val_accuracy: 0.7785 - val_loss: 1.0551 - learning_rate: 3.1250e-06
# Epoch 49/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9168 - loss: 0.5595 - val_accuracy: 0.7743 - val_loss: 1.0528 - learning_rate: 1.5625e-06
# Epoch 50/50
# 237/237 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9204 - loss: 0.5619 - val_accuracy: 0.7743 - val_loss: 1.0540 - learning_rate: 1.5625e-06

# %%
from google.colab import drive
drive.mount('/content/drive')
saved_model_path = '/content/drive/MyDrive'
# Out:
# Mounted at /content/drive

# %%
model.save(saved_model_path + '/FER_simple_CNN_Micro_Expressions.keras', overwrite=True)
model.save(saved_model_path + '/FER_simple_CNN_Micro_Expressions.h5',overwrite=True)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Load pretrained model (if necessary)
from tensorflow.keras.models import load_model
model = load_model(saved_model_path + '/FER_simple_CNN_Micro_Expressions.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'], label='Training Accuracy')
plt.plot(hist.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(hist.history['loss'], label='Training Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
loss, accuracy = model.evaluate(test_images, test_labels)
print(f'Validation Loss: {loss}')
print(f'Validation Accuracy: {accuracy}')
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7588 - loss: 1.1111
# Validation Loss: 1.0540382862091064
# Validation Accuracy: 0.7743129134178162

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

y_pred = model.predict(test_images)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(test_labels, axis=1)

# Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred_classes, target_names=class_names, digits=4))

# Additional metrics
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_true, y_pred_classes, average='weighted')
recall = recall_score(y_true, y_pred_classes, average='weighted')
f1 = f1_score(y_true, y_pred_classes, average='weighted')

print(f"\nWeighted Precision: {precision:.4f}")
print(f"Weighted Recall: {recall:.4f}")
print(f"Weighted F1-Score: {f1:.4f}")
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#        anger     0.9385    0.9333    0.9359       180
#      disgust     0.9365    0.8676    0.9008        68
#         fear     0.9636    0.7465    0.8413        71
#    happiness     0.9835    0.9794    0.9814       243
#      neutral     0.8444    0.9383    0.8889        81
#      sadness     0.9412    0.9412    0.9412       170
#     surprise     0.8980    0.9925    0.9429       133
#
#     accuracy                         0.9366       946
#    macro avg     0.9294    0.9141    0.9189       946
# weighted avg     0.9385    0.9366    0.9359       946
#
#
# Weighted Precision: 0.9385
# Weighted Recall: 0.9366
# Weighted F1-Score: 0.9359
